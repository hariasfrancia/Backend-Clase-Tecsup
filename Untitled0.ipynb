# %% [markdown]
# <a href="https://colab.research.google.com/github/hariasfrancia/Backend-Clase-Tecsup/blob/repaso-flask/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ventas = [1200, 950,1360, 880, 1020]
promedio = sum(ventas)/len(ventas)
print("Promedio de Ventas:",promedio)
# Out:
# Promedio de Ventas: 1082.0

# %%
numeros = [1,2,3,4]
fruta = ["manzana","fresa","uva"]
mixto = [1, "manzana", True]

print(numeros[0])

print(fruta[1])

print(mixto[2])

print(mixto[-3])
# Out:
# 1
# fresa
# True
# 1

# %%
numeros.append(300)
print(numeros)
# Out:
# [1, 2, 3, 4, 300]

# %%
numeros.insert(0,44)
print(numeros)
# Out:
# [44, 1, 2, 3, 4, 300]

# %%
numeros.remove(300)
print(numeros)
# Out:
# [44, 1, 2, 3, 4]

# %%
empleado = {
    "nombre":"Ana Pérez",
    "cargo": "Analista de Datos",
    "salario":3500
}

print("Empleado:", empleado["nombre"])
print("Salario:", empleado["salario"])
# Out:
# Empleado: Ana Pérez
# Salario: 3500

# %%
empleado["area"] = "BI"
empleado["salario"] += 500
print("Empleado Atualizado:", empleado)
# Out:
# Empleado Atualizado: {'nombre': 'Ana Pérez', 'cargo': 'Analista de Datos', 'salario': 4000, 'area': 'BI'}

# %%
venta = 1500
if venta > 1000:
  print("Excelente venta")
else:
  print("Venta baja")
# Out:
# Excelente venta

# %%
ventas = [800,1200,950,1400]
for monto in ventas:
  if monto >= 1000:
    print("Venta destacada: ",monto)
# Out:
# Venta destacada:  1200
# Venta destacada:  1400

# %%
contador = 0
while contador < 3:
  print("Iteracion: ", contador)
  contador += 1
# Out:
# Iteracion:  0
# Iteracion:  1
# Iteracion:  2
